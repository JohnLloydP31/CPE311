# %% [markdown]
# Problem: You are given an integer n. Determine if there is an unconnected graph with n vertices that contains at least two connected components and contains the number of edges that is equal to the number of vertices. Each vertex must follow one of these conditions:
#
# 1. Its degree is less than or equal to 1.
# 2. It's a cut-vertex.
#
# Note:
# * The graph must be simple.
# *Loops and multiple edges are not allowed.
#
# Input format:
# * First line: n
#
# Output format:
# * Print Yes if it is an unconnected graph. Otherwise, print No.
#
# Constraints:
# * 1 <= n <= 100

# %%
import networkx as nx
import matplotlib.pyplot as plt

graphs = {
          "a":{"b"},
          "b":{"c", "d"},
          "c":{"b", "d"},
          "d":{"b", "c"},
          "e":{"c"},
          "f":{"d"},
          "7":{"8"},
          "8":{"9", "10"},
          "9":{"8", "10"},
          "10":{"8", "9"},
          "11":{"9"},
          "12":{"10"},
          }

G = nx.Graph(graphs)

pos = nx.spring_layout(G, k=0.8, pos=None, fixed=None, iterations=100, threshold=0.0001, weight=4, scale=1.2, center=None, dim=2, seed=None)
nx.draw(G, pos, with_labels=True, node_size=1000, node_color='blue', font_size=10, font_weight='bold')
plt.title('Graph')
plt.show()

# %%
def unconnectedGraph(n):
  if 1 <= n and  n <= 100:
    if n < 12:
      print("No")
    else:
      print("Yes")
  else:
    return
n = int(input("Enter a number to determine if is unconnected: "))
unconnectedGraph(n)
# Out:
# Enter a number to determine if is unconnected: 13
# Yes
